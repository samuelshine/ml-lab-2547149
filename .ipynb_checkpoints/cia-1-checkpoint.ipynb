# %% [markdown]
# # CIA 1
# ## Part B

# %% [markdown]
# ### Question 1

# %% [markdown]
# Installing dependencies and importing libraries

# %%
# !pip3 install pandas numpy scikit-learn --break-system-packages
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.14/site-packages (3.0.3)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.14/site-packages (2.5.0)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.14/site-packages (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /opt/homebrew/lib/python3.14/site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in /opt/homebrew/lib/python3.14/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /opt/homebrew/lib/python3.14/site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /opt/homebrew/lib/python3.14/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data = pd.read_excel("data/QP_Data_road_accident_dataset_with_missing.xlsx")
pd.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_xlsx("data/QP_Data_road_accident_dataset_with_missing.xlsx")
#       2 pd.head()
#
# NameError: name 'pd' is not defined

# %%
data.select_dtypes(include=np.number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.select_dtypes(include=np.number)
#
# NameError: name 'df' is not defined
